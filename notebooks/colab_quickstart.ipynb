# %% [markdown]
# # NeuroAugment Colab quickstart

# %%
# !pip install -q numpy scipy scikit-learn torch click pyyaml matplotlib
from neuroaugment.simulator import Simulator
sim = Simulator('ecg', T=256, C=2)
X, y, meta = sim.sample_batch(4)
X.shape, y.shape
